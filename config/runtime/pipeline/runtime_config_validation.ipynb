# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============================================
# ICTA RUNTIME CONFIG VALIDATION
# ============================================

# ============================================
# ENVIRONMENT INITIALIZATION
# ============================================

# %run /content/drive/MyDrive/project_cd/config/environment.py

# ============================================
# IMPORTS
# ============================================

from config.runtime.runtime_config_loader import (
    RuntimeConfigLoader
)

# ============================================
# INITIALIZE LOADER
# ============================================

loader = RuntimeConfigLoader()

# ============================================
# LOAD ALERT CONFIG
# ============================================

alert_config = loader.load(

    category="alerts",

    filename="alert_thresholds.json"
)

# ============================================
# LOAD ORCHESTRATION CONFIG
# ============================================

orchestration_config = loader.load(

    category="orchestration",

    filename="orchestration_config.json"
)

# ============================================
# LOAD PREDICTION CONFIG
# ============================================

prediction_config = loader.load(

    category="prediction",

    filename="prediction_config.json"
)

# ============================================
# LOAD OBSERVABILITY CONFIG
# ============================================

observability_config = loader.load(

    category="observability",

    filename="monitoring_config.json"
)

# ============================================
# LOAD AI CONFIG
# ============================================

ai_config = loader.load(

    category="ai",

    filename="reasoning_config.json"
)

# ============================================
# LOAD MEMORY CONFIG
# ============================================

memory_config = loader.load(

    category="memory",

    filename="learning_config.json"
)

# ============================================
# DISPLAY ALERT CONFIG
# ============================================

loader.display(alert_config)

# ============================================
# DISPLAY ORCHESTRATION CONFIG
# ============================================

loader.display(orchestration_config)

# ============================================
# DISPLAY PREDICTION CONFIG
# ============================================

loader.display(prediction_config)

# ============================================
# DISPLAY OBSERVABILITY CONFIG
# ============================================

loader.display(observability_config)

# ============================================
# DISPLAY AI CONFIG
# ============================================

loader.display(ai_config)

# ============================================
# DISPLAY MEMORY CONFIG
# ============================================

loader.display(memory_config)

# ============================================
# FINAL STATUS
# ============================================

print("\n")
print("=" * 60)

print("ICTA RUNTIME CONFIG VALIDATION COMPLETE")

print("=" * 60)
# Out:
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All project paths initialized ✅
#
#
# ...
# ICTA PROJECT VALIDATOR
# ...
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ...
#
#
# ...
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ...
#
# Runtime config loaded ✅
#
# Category: alerts
# File: alert_thresholds.json
#
# Runtime config loaded ✅
#
# Category: orchestration
# File: orchestration_config.json
#
# Runtime config loaded ✅
#
# Category: prediction
# File: prediction_config.json
#
# Runtime config loaded ✅
#
# Category: observability
# File: monitoring_config.json
#
# Runtime config loaded ✅
#
# Category: ai
# ...
