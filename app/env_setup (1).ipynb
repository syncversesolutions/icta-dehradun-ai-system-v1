# %%
# =====================================================
# MOUNT GOOGLE DRIVE
# =====================================================
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# =====================================================
# Install Dependcies should be run only once.
# =====================================================
# %run /content/drive/MyDrive/project_cd/app/install_dependencies.py


# =====================================================
# ICTA ENVIRONMENT SETUP
# =====================================================
print("\n====================================")
print("ICTA ENVIRONMENT SETUP")
print("====================================\n")
# %run /content/drive/MyDrive/project_cd/config/environment.py


# =====================================================
# RUN MASTER PIPELINE
# =====================================================
print("\n====================================")
print("RUNNING MASTER PIPELINE")
print("====================================\n")
# %run /content/drive/MyDrive/project_cd/system/orchestration/pipelines/operational/master_pipeline.ipynb


# =====================================================
# LAUNCH DASHBOARD RUNTIME
# =====================================================
print("\n====================================")
print("LAUNCHING ICTA DASHBOARD")
print("====================================\n")
# %run /content/drive/MyDrive/project_cd/app/runner.py
# Out:
# Installing streamlit...
#
# Installing streamlit-autorefresh...
#
# Installing pyngrok...
#
# Installing requests...
#
# All dashboard dependencies installed ✅
#
# ====================================
# ICTA ENVIRONMENT SETUP
# ====================================
#
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All project paths initialized ✅
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# ====================================
# RUNNING MASTER PIPELINE
# ====================================
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ====================================
# ICTA MASTER PIPELINE STARTING
# ====================================
#
#
# STEP 0 — Environment Setup
#
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# ====================================
# TRAFFIC DOMAIN
# ====================================
#
#
# STEP 1 — Traffic Ingestion
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Checkpoint Path:
# /content/drive/MyDrive/project_cd/domains/traffic/data/raw/checkpoint_logs.csv
#
# Crowd Path:
# /content/drive/MyDrive/project_cd/domains/traffic/data/raw/crowd_density_logs.csv
#
# Loading raw datasets...
#
# Checkpoint Dataset Columns:
# ['calendar_date', 'route_id', 'checkpoint_name', 'throughput_count', 'congestion_level']
#
# Crowd Dataset Columns:
# ['calendar_date', 'location_id', 'pilgrim_count', 'density_level', 'avg_queue_minutes']
#
# Aligned rows: 60
#
# Final Traffic Dataset Shape:
# (60, 6)
#
# Final Traffic Dataset Columns:
# ['calendar_date', 'route_id', 'checkpoint_name', 'vehicle_count', 'congestion_level', 'crowd_density']
#
# Final Traffic Dataset Sample:
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# 0    2026-05-01     R001   Sonprayag Checkpoint            283
# 1    2026-05-01     R002        Kedar Trek Gate            166
# 2    2026-05-01     R003      Joshimath Barrier            263
# 3    2026-05-01     R004             Badri Gate            186
# 4    2026-05-01     R005  Uttarkashi Checkpoint            290
#
#   congestion_level  crowd_density
# 0              Low              3
# 1           Medium              2
# 2              Low              1
# 3             High              1
# 4              Low              3
#
# Saved cleaned data at:
# /content/drive/MyDrive/project_cd/domains/traffic/data/processed/cleaned_traffic.csv
#
# Traffic ingestion complete ✅
#
# STEP 2 — Traffic Validation
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Loading cleaned traffic dataset...
# /content/drive/MyDrive/project_cd/domains/traffic/data/processed/cleaned_traffic.csv
#
# Input Dataset Shape:
# (60, 6)
#
# Input Dataset Columns:
# ['calendar_date', 'route_id', 'checkpoint_name', 'vehicle_count', 'congestion_level', 'crowd_density']
#
# Input Dataset Sample:
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# 0    2026-05-01     R001   Sonprayag Checkpoint            283
# 1    2026-05-01     R002        Kedar Trek Gate            166
# 2    2026-05-01     R003      Joshimath Barrier            263
# 3    2026-05-01     R004             Badri Gate            186
# 4    2026-05-01     R005  Uttarkashi Checkpoint            290
#
#   congestion_level  crowd_density
# 0              Low              3
# 1           Medium              2
# 2              Low              1
# 3             High              1
# 4              Low              3
#    calendar_date route_id          checkpoint_name  vehicle_count  \
# 0     2026-05-01     R001     Sonprayag Checkpoint            283
# 1     2026-05-01     R002          Kedar Trek Gate            166
# 2     2026-05-01     R003        Joshimath Barrier            263
# 3     2026-05-01     R004               Badri Gate            186
# 4     2026-05-01     R005    Uttarkashi Checkpoint            290
# 5     2026-05-01     R006            Gangotri Gate            133
# 6     2026-05-01     R007  Janki Chatti Checkpoint            318
# 7     2026-05-01     R008         Yamuna Trek Gate            146
# 8     2026-05-02     R001     Sonprayag Checkpoint            371
# 9     2026-05-02     R002          Kedar Trek Gate            225
# 10    2026-05-02     R003        Joshimath Barrier            361
# 11    2026-05-02     R004               Badri Gate            216
# 12    2026-05-02     R005    Uttarkashi Checkpoint            377
# 13    2026-05-02     R006            Gangotri Gate            187
# 14    2026-05-02     R007  Janki Chatti Checkpoint            341
# 15    2026-05-02     R008         Yamuna Trek Gate            190
# 16    2026-05-03     R001     Sonprayag Checkpoint            330
# 17    2026-05-03     R002          Kedar Trek Gate            279
# 18    2026-05-03     R003        Joshimath Barrier            317
# 19    2026-05-03     R004               Badri Gate            238
# 20    2026-05-03     R005    Uttarkashi Checkpoint            360
# 21    2026-05-03     R006            Gangotri Gate            218
# 22    2026-05-03     R007  Janki Chatti Checkpoint            388
# 23    2026-05-03     R008         Yamuna Trek Gate            224
# 24    2026-05-04     R001     Sonprayag Checkpoint            256
# 25    2026-05-04     R002          Kedar Trek Gate            199
# 26    2026-05-04     R003        Joshimath Barrier            277
# 27    2026-05-04     R004               Badri Gate            160
# 28    2026-05-04     R005    Uttarkashi Checkpoint            262
# 29    2026-05-04     R006            Gangotri Gate            177
# 30    2026-05-04     R007  Janki Chatti Checkpoint            297
# 31    2026-05-04     R008         Yamuna Trek Gate            178
# 32    2026-05-05     R001     Sonprayag Checkpoint            281
# 33    2026-05-05     R002          Kedar Trek Gate            170
# 34    2026-05-05     R003        Joshimath Barrier            271
# 35    2026-05-05     R004               Badri Gate            157
# 36    2026-05-05     R005    Uttarkashi Checkpoint            221
# 37    2026-05-05     R006            Gangotri Gate            197
# 38    2026-05-05     R007  Janki Chatti Checkpoint            288
# 39    2026-05-05     R008         Yamuna Trek Gate            154
# 40    2026-05-06     R001     Sonprayag Checkpoint            241
# 41    2026-05-06     R002          Kedar Trek Gate            186
# 42    2026-05-06     R003        Joshimath Barrier            304
# 43    2026-05-06     R004               Badri Gate            190
# 44    2026-05-06     R005    Uttarkashi Checkpoint            270
# 45    2026-05-06     R006            Gangotri Gate            178
# 46    2026-05-06     R007  Janki Chatti Checkpoint            267
# 47    2026-05-06     R008         Yamuna Trek Gate            180
# 48    2026-05-07     R001     Sonprayag Checkpoint            304
# 49    2026-05-07     R002          Kedar Trek Gate            180
# 50    2026-05-07     R003        Joshimath Barrier            267
# 51    2026-05-07     R004               Badri Gate            179
# 52    2026-05-07     R005    Uttarkashi Checkpoint            278
# 53    2026-05-07     R006            Gangotri Gate            169
# 54    2026-05-07     R007  Janki Chatti Checkpoint            292
# 55    2026-05-07     R008         Yamuna Trek Gate            211
# 56    2026-05-08     R001     Sonprayag Checkpoint            286
# 57    2026-05-08     R002          Kedar Trek Gate            195
# 58    2026-05-08     R003        Joshimath Barrier            278
# 59    2026-05-08     R004               Badri Gate            155
#
#    congestion_level  crowd_density
# 0               Low              3
# 1            Medium              2
# 2               Low              1
# 3              High              1
# 4               Low              3
# 5               Low              3
# 6              High              1
# 7              High              2
# 8              High              3
# 9            Medium              3
# 10             High              2
# 11             High              2
# 12             High              3
# 13              Low              2
# 14             High              2
# 15           Medium              1
# 16             High              3
# 17           Medium              2
# 18           Medium              1
# 19           Medium              1
# 20             High              3
# 21           Medium              2
# 22             High              1
# 23           Medium              1
# 24              Low              3
# 25           Medium              2
# 26              Low              1
# 27             High              1
# 28              Low              3
# 29              Low              2
# 30              Low              2
# 31           Medium              1
# 32              Low              3
# 33           Medium              3
# 34              Low              2
# 35           Medium              1
# 36              Low              3
# 37              Low              3
# 38              Low              2
# 39             High              2
# 40              Low              2
# 41           Medium              2
# 42              Low              2
# 43             High              1
# 44              Low              2
# 45              Low              2
# 46           Medium              1
# 47           Medium              1
# 48              Low              3
# 49             High              2
# 50              Low              2
# 51             High              1
# 52              Low              2
# 53              Low              2
# 54              Low              1
# 55             High              1
# 56              Low              3
# 57             High              2
# 58              Low              1
# 59             High              1
#
# Starting traffic validation...
#
# Initial Shape:
# (60, 6)
#
# Removed duplicates: 0
#
# Removed invalid dates: 0
#
# Removed invalid throughput rows: 0
#
# Removed negative throughput rows: 0
#
# Removed invalid congestion levels: 0
#
# Final Shape:
# (60, 6)
#
# Validated Dataset Sample:
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# 0    2026-05-01     R001   Sonprayag Checkpoint            283
# 1    2026-05-01     R002        Kedar Trek Gate            166
# 2    2026-05-01     R003      Joshimath Barrier            263
# 3    2026-05-01     R004             Badri Gate            186
# 4    2026-05-01     R005  Uttarkashi Checkpoint            290
#
#   congestion_level  crowd_density
# 0              Low              3
# 1           Medium              2
# 2              Low              1
# 3             High              1
# 4              Low              3
#
# Validated Dataset Shape:
# (60, 6)
#
# Validated data saved at:
# /content/drive/MyDrive/project_cd/domains/traffic/data/validated/validated_traffic.csv
#
# Traffic validation complete ✅
#
# STEP 3 — KPI Engineering
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# 0    2026-05-01     R001   Sonprayag Checkpoint            283
# 1    2026-05-01     R002        Kedar Trek Gate            166
# 2    2026-05-01     R003      Joshimath Barrier            263
# 3    2026-05-01     R004             Badri Gate            186
# 4    2026-05-01     R005  Uttarkashi Checkpoint            290
#
#   congestion_level  crowd_density  congestion_score  traffic_volume  \
# 0              Low              3                 1             283
# 1           Medium              2                 2             166
# 2              Low              1                 1             263
# 3             High              1                 3             186
# 4              Low              3                 1             290
#
#    crowd_pressure
# 0             849
# 1             332
# 2             263
# 3             186
# 4             870
#    calendar_date route_id          checkpoint_name  vehicle_count  \
# 0     2026-05-01     R001     Sonprayag Checkpoint            283
# 1     2026-05-01     R002          Kedar Trek Gate            166
# 2     2026-05-01     R003        Joshimath Barrier            263
# 3     2026-05-01     R004               Badri Gate            186
# 4     2026-05-01     R005    Uttarkashi Checkpoint            290
# 5     2026-05-01     R006            Gangotri Gate            133
# 6     2026-05-01     R007  Janki Chatti Checkpoint            318
# 7     2026-05-01     R008         Yamuna Trek Gate            146
# 8     2026-05-02     R001     Sonprayag Checkpoint            371
# 9     2026-05-02     R002          Kedar Trek Gate            225
# 10    2026-05-02     R003        Joshimath Barrier            361
# 11    2026-05-02     R004               Badri Gate            216
# 12    2026-05-02     R005    Uttarkashi Checkpoint            377
# 13    2026-05-02     R006            Gangotri Gate            187
# 14    2026-05-02     R007  Janki Chatti Checkpoint            341
# 15    2026-05-02     R008         Yamuna Trek Gate            190
# 16    2026-05-03     R001     Sonprayag Checkpoint            330
# 17    2026-05-03     R002          Kedar Trek Gate            279
# 18    2026-05-03     R003        Joshimath Barrier            317
# 19    2026-05-03     R004               Badri Gate            238
# 20    2026-05-03     R005    Uttarkashi Checkpoint            360
# 21    2026-05-03     R006            Gangotri Gate            218
# 22    2026-05-03     R007  Janki Chatti Checkpoint            388
# 23    2026-05-03     R008         Yamuna Trek Gate            224
# 24    2026-05-04     R001     Sonprayag Checkpoint            256
# 25    2026-05-04     R002          Kedar Trek Gate            199
# 26    2026-05-04     R003        Joshimath Barrier            277
# 27    2026-05-04     R004               Badri Gate            160
# 28    2026-05-04     R005    Uttarkashi Checkpoint            262
# 29    2026-05-04     R006            Gangotri Gate            177
# 30    2026-05-04     R007  Janki Chatti Checkpoint            297
# 31    2026-05-04     R008         Yamuna Trek Gate            178
# 32    2026-05-05     R001     Sonprayag Checkpoint            281
# 33    2026-05-05     R002          Kedar Trek Gate            170
# 34    2026-05-05     R003        Joshimath Barrier            271
# 35    2026-05-05     R004               Badri Gate            157
# 36    2026-05-05     R005    Uttarkashi Checkpoint            221
# 37    2026-05-05     R006            Gangotri Gate            197
# 38    2026-05-05     R007  Janki Chatti Checkpoint            288
# 39    2026-05-05     R008         Yamuna Trek Gate            154
# 40    2026-05-06     R001     Sonprayag Checkpoint            241
# 41    2026-05-06     R002          Kedar Trek Gate            186
# 42    2026-05-06     R003        Joshimath Barrier            304
# 43    2026-05-06     R004               Badri Gate            190
# 44    2026-05-06     R005    Uttarkashi Checkpoint            270
# 45    2026-05-06     R006            Gangotri Gate            178
# 46    2026-05-06     R007  Janki Chatti Checkpoint            267
# 47    2026-05-06     R008         Yamuna Trek Gate            180
# 48    2026-05-07     R001     Sonprayag Checkpoint            304
# 49    2026-05-07     R002          Kedar Trek Gate            180
# 50    2026-05-07     R003        Joshimath Barrier            267
# 51    2026-05-07     R004               Badri Gate            179
# 52    2026-05-07     R005    Uttarkashi Checkpoint            278
# 53    2026-05-07     R006            Gangotri Gate            169
# 54    2026-05-07     R007  Janki Chatti Checkpoint            292
# 55    2026-05-07     R008         Yamuna Trek Gate            211
# 56    2026-05-08     R001     Sonprayag Checkpoint            286
# 57    2026-05-08     R002          Kedar Trek Gate            195
# 58    2026-05-08     R003        Joshimath Barrier            278
# 59    2026-05-08     R004               Badri Gate            155
#
#    congestion_level  crowd_density  congestion_score  traffic_volume  \
# 0               Low              3                 1             283
# 1            Medium              2                 2             166
# 2               Low              1                 1             263
# 3              High              1                 3             186
# 4               Low              3                 1             290
# 5               Low              3                 1             133
# 6              High              1                 3             318
# 7              High              2                 3             146
# 8              High              3                 3             371
# 9            Medium              3                 2             225
# 10             High              2                 3             361
# 11             High              2                 3             216
# 12             High              3                 3             377
# 13              Low              2                 1             187
# 14             High              2                 3             341
# 15           Medium              1                 2             190
# 16             High              3                 3             330
# 17           Medium              2                 2             279
# 18           Medium              1                 2             317
# 19           Medium              1                 2             238
# 20             High              3                 3             360
# 21           Medium              2                 2             218
# 22             High              1                 3             388
# 23           Medium              1                 2             224
# 24              Low              3                 1             256
# 25           Medium              2                 2             199
# 26              Low              1                 1             277
# 27             High              1                 3             160
# 28              Low              3                 1             262
# 29              Low              2                 1             177
# 30              Low              2                 1             297
# 31           Medium              1                 2             178
# 32              Low              3                 1             281
# 33           Medium              3                 2             170
# 34              Low              2                 1             271
# 35           Medium              1                 2             157
# 36              Low              3                 1             221
# 37              Low              3                 1             197
# 38              Low              2                 1             288
# 39             High              2                 3             154
# 40              Low              2                 1             241
# 41           Medium              2                 2             186
# 42              Low              2                 1             304
# 43             High              1                 3             190
# 44              Low              2                 1             270
# 45              Low              2                 1             178
# 46           Medium              1                 2             267
# 47           Medium              1                 2             180
# 48              Low              3                 1             304
# 49             High              2                 3             180
# 50              Low              2                 1             267
# 51             High              1                 3             179
# 52              Low              2                 1             278
# 53              Low              2                 1             169
# 54              Low              1                 1             292
# 55             High              1                 3             211
# 56              Low              3                 1             286
# 57             High              2                 3             195
# 58              Low              1                 1             278
# 59             High              1                 3             155
#
#     crowd_pressure
# 0              849
# 1              332
# 2              263
# 3              186
# 4              870
# 5              399
# 6              318
# 7              292
# 8             1113
# 9              675
# 10             722
# 11             432
# 12            1131
# 13             374
# 14             682
# 15             190
# 16             990
# 17             558
# 18             317
# 19             238
# 20            1080
# 21             436
# 22             388
# 23             224
# 24             768
# 25             398
# 26             277
# 27             160
# 28             786
# 29             354
# 30             594
# 31             178
# 32             843
# 33             510
# 34             542
# 35             157
# 36             663
# 37             591
# 38             576
# 39             308
# 40             482
# 41             372
# 42             608
# 43             190
# 44             540
# 45             356
# 46             267
# 47             180
# 48             912
# 49             360
# 50             534
# 51             179
# 52             556
# 53             338
# 54             292
# 55             211
# 56             858
# 57             390
# 58             278
# 59             155
# Traffic KPI Engineering complete ✅
#
# STEP 4 — Feature Engineering
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# 0    2026-05-01     R001   Sonprayag Checkpoint            283
# 1    2026-05-01     R002        Kedar Trek Gate            166
# 2    2026-05-01     R003      Joshimath Barrier            263
# 3    2026-05-01     R004             Badri Gate            186
# 4    2026-05-01     R005  Uttarkashi Checkpoint            290
#
#   congestion_level  crowd_density  congestion_score  traffic_volume  \
# 0              Low              3                 1             283
# 1           Medium              2                 2             166
# 2              Low              1                 1             263
# 3             High              1                 3             186
# 4              Low              3                 1             290
#
#    crowd_pressure  vehicle_density_ratio  crowd_vehicle_interaction  \
# 0             849              70.750000                        849
# 1             332              55.333333                        332
# 2             263             131.500000                        263
# 3             186              93.000000                        186
# 4             870              72.500000                        870
#
#    high_congestion_flag  day_of_week  is_weekend
# 0                     0            4           0
# 1                     0            4           0
# 2                     0            4           0
# 3                     1            4           0
# 4                     0            4           0
# Traffic Feature Engineering complete ✅
#
# STEP 5 — Traffic Prediction
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
# Traffic feature dataset loaded ✅
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# 0    2026-05-01     R001   Sonprayag Checkpoint            283
# 1    2026-05-01     R002        Kedar Trek Gate            166
# 2    2026-05-01     R003      Joshimath Barrier            263
# 3    2026-05-01     R004             Badri Gate            186
# 4    2026-05-01     R005  Uttarkashi Checkpoint            290
#
#   congestion_level  crowd_density  congestion_score  traffic_volume  \
# 0              Low              3                 1             283
# 1           Medium              2                 2             166
# 2              Low              1                 1             263
# 3             High              1                 3             186
# 4              Low              3                 1             290
#
#    crowd_pressure  vehicle_density_ratio  crowd_vehicle_interaction  \
# 0             849              70.750000                        849
# 1             332              55.333333                        332
# 2             263             131.500000                        263
# 3             186              93.000000                        186
# 4             870              72.500000                        870
#
#    high_congestion_flag  day_of_week  is_weekend
# 0                     0            4           0
# 1                     0            4           0
# 2                     0            4           0
# 3                     1            4           0
# 4                     0            4           0
# Congestion model trained ✅
#
# Model Evaluation Metrics
# {'MAE': 0.2165, 'MSE': 0.0873, 'R2_SCORE': 0.8814}
#
# Prediction sample:
#   route_id        checkpoint_name congestion_level  \
# 0     R001   Sonprayag Checkpoint              Low
# 1     R002        Kedar Trek Gate           Medium
# 2     R003      Joshimath Barrier              Low
# 3     R004             Badri Gate             High
# 4     R005  Uttarkashi Checkpoint              Low
#
#    predicted_congestion_score predicted_risk_level
# 0                    1.033031                  Low
# 1                    1.379605                  Low
# 2                    1.349286                  Low
# 3                    3.084250                 High
# 4                    1.020135                  Low
#
# Predictions saved at: /content/drive/MyDrive/project_cd/domains/traffic/data/predictions/traffic_predictions.csv
# Traffic Prediction Pipeline complete ✅
#
# STEP 6 — Traffic Signal Generation
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Prediction Dataset Shape:
# (60, 16)
#
# Generated Signals: 19
#
# Signals saved at:
# /content/drive/MyDrive/project_cd/domains/traffic/signals/signals.json
#
# Sample Signals:
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R004', 'checkpoint_name': 'Badri Gate', 'risk_level': 'High', 'predicted_score': 3.084250116098573, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R007', 'checkpoint_name': 'Janki Chatti Checkpoint', 'risk_level': 'High', 'predicted_score': 2.6826139430216083, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R008', 'checkpoint_name': 'Yamuna Trek Gate', 'risk_level': 'High', 'predicted_score': 2.937190948622169, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R001', 'checkpoint_name': 'Sonprayag Checkpoint', 'risk_level': 'High', 'predicted_score': 2.9478494410071043, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R003', 'checkpoint_name': 'Joshimath Barrier', 'risk_level': 'High', 'predicted_score': 2.9016769797248303, 'recommended_action': 'Increase traffic monitoring'}
#
# Signal generation complete ✅
#
# ====================================
# SYSTEM SIGNAL LAYER
# ====================================
#
#
# STEP 7 — Aggregate Signals
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Traffic Signals Loaded: 19
#
# Total Aggregated Signals: 19
#
# Sample Signals:
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R004', 'checkpoint_name': 'Badri Gate', 'risk_level': 'High', 'predicted_score': 3.084250116098573, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R007', 'checkpoint_name': 'Janki Chatti Checkpoint', 'risk_level': 'High', 'predicted_score': 2.6826139430216083, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R008', 'checkpoint_name': 'Yamuna Trek Gate', 'risk_level': 'High', 'predicted_score': 2.937190948622169, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R001', 'checkpoint_name': 'Sonprayag Checkpoint', 'risk_level': 'High', 'predicted_score': 2.9478494410071043, 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R003', 'checkpoint_name': 'Joshimath Barrier', 'risk_level': 'High', 'predicted_score': 2.9016769797248303, 'recommended_action': 'Increase traffic monitoring'}
#
# All signals saved at:
# /content/drive/MyDrive/project_cd/system/signals/all_signals.json
#
# Central signal aggregation complete ✅
#
# ====================================
# GRAPH INTELLIGENCE
# ====================================
#
#
# STEP 8 — Impact Analysis
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Signals Loaded: 19
#
# Dependency graph loaded ✅
#
# Impact Analyses Generated: 19
#
# Sample Impact Analysis:
#
# {'signal': {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R004', 'checkpoint_name': 'Badri Gate', 'risk_level': 'High', 'predicted_score': 3.084250116098573, 'recommended_action': 'Increase traffic monitoring'}, 'downstream_impacts': []}
# {'signal': {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R007', 'checkpoint_name': 'Janki Chatti Checkpoint', 'risk_level': 'High', 'predicted_score': 2.6826139430216083, 'recommended_action': 'Increase traffic monitoring'}, 'downstream_impacts': []}
# {'signal': {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R008', 'checkpoint_name': 'Yamuna Trek Gate', 'risk_level': 'High', 'predicted_score': 2.937190948622169, 'recommended_action': 'Increase traffic monitoring'}, 'downstream_impacts': []}
#
# Impact analysis saved at:
# /content/drive/MyDrive/project_cd/system/graph/impact_analysis.json
#
# AI impact analysis complete ✅
#
# ====================================
# AI ALERT TOWER
# ====================================
#
#
# STEP 9 — Alert Tower
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Impact Analyses Loaded: 19
#
# Total Active Alerts: 19
#
# Top Alerts:
#
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R004', 'checkpoint_name': 'Badri Gate', 'risk_level': 'High', 'priority': 'HIGH', 'severity_score': 3, 'downstream_impacts': [], 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R007', 'checkpoint_name': 'Janki Chatti Checkpoint', 'risk_level': 'High', 'priority': 'HIGH', 'severity_score': 3, 'downstream_impacts': [], 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R008', 'checkpoint_name': 'Yamuna Trek Gate', 'risk_level': 'High', 'priority': 'HIGH', 'severity_score': 3, 'downstream_impacts': [], 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R001', 'checkpoint_name': 'Sonprayag Checkpoint', 'risk_level': 'High', 'priority': 'HIGH', 'severity_score': 3, 'downstream_impacts': [], 'recommended_action': 'Increase traffic monitoring'}
# {'domain': 'traffic', 'signal_type': 'high_congestion', 'route_id': 'R003', 'checkpoint_name': 'Joshimath Barrier', 'risk_level': 'High', 'priority': 'HIGH', 'severity_score': 3, 'downstream_impacts': [], 'recommended_action': 'Increase traffic monitoring'}
#
# Active alerts saved at:
# /content/drive/MyDrive/project_cd/system/ai/active_alerts.json
#
# AI Alert Tower complete ✅
#
# ====================================
# STATE CHANGE DETECTOR
# ====================================
#
#
#
# ============================================================
# STATE CHANGE DETECTOR
# ============================================================
#
# Risk Level:
# high
#
# Critical Domains:
# • traffic
#
# Active Signals:
# • traffic_congestion
#
#
# ============================================================
#
# ====================================
# AI AGENT EXECUTION
# ====================================
#
#
#
# ============================================================
# AGENT REGISTRY
# ============================================================
# state_analyst_agent | Enabled: True | Priority: 1
# dependency_agent | Enabled: True | Priority: 2
# recommendation_agent | Enabled: True | Priority: 3
# chief_orchestrator_agent | Enabled: True | Priority: 4
# ============================================================
#
#
# ============================================================
# AGENT MANAGER
# ============================================================
#
# Running: state_analyst_agent
#
# Running: dependency_agent
#
# Running: recommendation_agent
#
# Running: chief_orchestrator_agent
#
#
# Execution Complete
# 2026-06-12 15:41:59.519194
# ============================================================
#
# ====================================
# WORKFLOW EXECUTION
# ====================================
#
#
#
# ============================================================
# WORKFLOW ENGINE
# ============================================================
#
# Executed 6 workflows
#
#
# ============================================================
#
# Workflow Engine Executed
#
# ====================================
# EPISODIC MEMORY
# ====================================
#
#
# Episode stored ✅
#
# ====================================
# LEARNING ENGINE
# ====================================
#
#
# Operational feedback captured ✅
#
# Learning cycle complete ✅
#
# ====================================
# RISK FORECASTING
# ====================================
#
#
# SAVE PATH:
# /content/drive/MyDrive/project_cd/system/prediction/forecasts/latest_forecast.json
# BASE_DIR: /content/drive/MyDrive/project_cd
#
# Risk forecasting complete ✅
#
# ====================================
# SCENARIO SIMULATION
# ====================================
#
#
# Scenario simulation complete ✅
#
# ====================================
# AUTONOMOUS CONTROLLER
# ====================================
#
#
# Workflow created ✅
#
#
# ============================================================
# EXECUTING: adaptive_response
# ============================================================
#
# ✓ activate rerouting
#
# ✓ enable redistribution
#
# ✓ increase medical deployment
#
# Workflow execution complete ✅
#
# Adaptive execution started ✅
# ✓ activate rerouting
# ✓ enable redistribution
# ✓ increase medical deployment
#
# Adaptive execution complete ✅
#
# ====================================
# GLOBAL STATE AGGATION
# ====================================
#
#
# Global state aggregated ✅
#
# ====================================
# ICTA V1 COMPLETE
# ====================================
#
# Risk Level:
# high
#
# Critical Domains:
# ['traffic']
#
# Forecast Count:
# 1
#
# Scenario Count:
# 3
#
# Memory Episodes:
# 23
#
# Autonomous Actions:
# 3
#
# System Ready For Dashboard Runtime ✅
#
# ====================================
# LAUNCHING ICTA DASHBOARD
# ====================================
#
#
# Starting ICTA dashboard...
#
# Streamlit server started ✅
#
#
# ============================================================
# ICTA DASHBOARD LIVE
# ============================================================
#
# Public URL:
# https://unopened-mammal-mossy.ngrok-free.dev
#
#
# ============================================================

# %% [markdown]
# env_setup.ipynb
#         │
#         ▼
#
# environment.py
#
#         │
#         ▼
#
# master_pipeline.ipynb
#
#         │
#         ▼
#
# Traffic Pipeline
# Signals
# Impact Analysis
# Alerts
# State Detection
# Agents
# Workflows
# Memory
# Learning
# Forecasting
# Simulation
# Autonomy
# State Aggregation
#
#         │
#         ▼
#
# global_state.json
# latest_forecast.json
# latest_scenarios.json
# autonomy_state.json
#
#         │
#         ▼
#
# runner.py
#
#         │
#         ▼
#
# app.py
#
#         │
#         ▼
#
# Dashboard

# %% [markdown]
# Verify these files are being generated every run, once these six files are update correctly the backend of ICTA V1 is essentially completed and the next focus should be rugning app.py into prefessional command-center dashbaord
#
#
#
# system/state/global/global_state.json
#
# system/prediction/forecasts/latest_forecast.json
#
# system/prediction/scenarios/latest_scenarios.json
#
# system/autonomy/state/autonomy_state.json
#
# system/memory/history/episodic_memory.json
#
# system/state/workflows/workflow_history.json
